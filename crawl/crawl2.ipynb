# %%
import requests
import re
from openpyxl import Workbook

url = "https://openapi.naver.com/v1/search/book.json"

start=1
headers = {
    "X-Naver-Client-Id" : 'Ys3w15bcN2xSNC13UEvg',
    "X-Naver-Client-Secret" : 'aCgPAsVse3'
}


book_csv_list = []
no = 1

for idx in range(10):
    # idx : 0
    start_num = start + (idx * 100)

    params = {
        "query":"주식",
        "display":"100",
        "start":str(start_num)
    }
    res = requests.get(url, params=params, headers=headers)
    contents = res.json()
    # print(res.url)

    for book in contents['items']:
        # print(book['title'], book['author'], book['discount'], book['publisher'])
        book_csv_list.append([no, book['title'], book['author'], book['discount'], book['publisher']])
        no += 1
print(book_csv_list)
# Out:
# [[1, '나는 월급쟁이 배당 부자가 되었다 (배당투자로 월 300만 원 제2의 월급 만드는 시스템)', '환상감자(이은호)', '19800', '길벗'], [2, '완벽한 종목 추천 (종목 발굴부터 피칭까지 월가의 실전 투자 수업)', '폴 손킨^폴 존슨', '22500', '에프엔미디어'], [3, '허영만의 주식 타짜 ― 슈퍼개미 이세무사', '허영만', '15120', '가디언'], [4, '손실은 짧게 수익은 길게 (자기만의 손익비를 찾아라!)', '깡토', '22500', '이레미디어'], [5, '켄 피셔 불변의 차트 90 (극심한 변동성에도 살아남는 대가의 투자법)', '켄 피셔', '27000', '한국경제신문'], [6, '실패를 성공으로 바꾸는 주식투자의 기술 (초보 투자자를 위한 부자아빠의 핵심 트레이닝)', '정재호', '18900', '프런트페이지'], [7, '성공적인 개인 투자를 위한 ETF 안내서', '안해성', '17820', '지음미디어'], [8, '평생 투자자 (일본 주식시장의 판을 흔들어 깨운 담대한 도전들)', '무라카미 요시아키', '19800', '에프엔미디어'], [9, 'AI 텐베거 투자 (뉴사이클에 진입한 AI 혁명 산업, 10배 종목 발굴을 위한 전략서)', '이형수', '35010', '지베르니'], [10, '해외선물 처음공부 (단돈 100만 원으로 달러, 금, 오일, 나스닥선물을 시작할 수 있는)', '김직선', '22500', '이레미디어'], [11, '미국 주식이 답이다 2026 (차근차근 부자 되는 미국 주식투자 입문서)', '장우석^이항영', '23400', '페이지2북스'], [12, '돈, 뜨겁게 사랑하고 차갑게 다루어라', '앙드레 코스톨라니', '10800', '미래의창'], [13, '단 3개의 미국 ETF로 은퇴하라 (원하는 삶을 앞당기는 돈 자동 사냥 시스템)', '김지훈(포메뽀꼬)', '17820', '리더스북'], [14, '월가의 영웅 (주식투자에서 상식으로 성공하는 법)'
# ...

# %%
# csv 저장
import csv

with open("./data/books.csv","w",encoding="utf-8",newline='') as f:
    wt = csv.writer(f)
    wt.writerows(book_csv_list)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 4
#       1 # csv 저장
#       2 import csv
# ----> 4 with open("./data/books.csv","w",encoding="utf-8",newline='') as f:
#       5     wt = csv.writer(f)
#       6     wt.writerows(book_csv_list)
#
# File c:\source\pythonsource\venv\Lib\site-packages\IPython\core\interactiveshell.py:326, in _modified_open(file, *args, **kwargs)
#     319 if file in {0, 1, 2}:
#     320     raise ValueError(
#     321         f"IPython won't let you open fd={file} by default "
#     322         "as it is likely to crash IPython. If you know what you are doing, "
#     323         "you can use builtins' open."
#     324     )
# --> 326 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/books.csv'

# %%
# 몽고디비

url = "https://openapi.naver.com/v1/search/book.json"

start=1
headers = {
    "X-Naver-Client-Id" : 'Ys3w15bcN2xSNC13UEvg',
    "X-Naver-Client-Secret" : 'aCgPAsVse3'
}


book_list = []

for idx in range(10):
    # idx : 0
    start_num = start + (idx * 100)

    params = {
        "query":"주식",
        "display":"100",
        "start":str(start_num)
    }
    res = requests.get(url, params=params, headers=headers)
    contents = res.json()
    # print(res.url)

    for book in contents['items']:
        # print(book['title'], book['author'], book['discount'], book['publisher'])

        book = {
            "title":book['title'],
            "author":book['author'],
            "price":book['discount'],
            "publisher":book['publisher']
        }
        book_list.append(book)

# %%
# 몽고디비 저장

from pymongo import MongoClient

client = MongoClient("mongodb+srv://test:QoH9OmGiFHHBY2iz@cluster0.09vhloc.mongodb.net/")
# 컬렉션 가져오기
db = client['test']
books = db.books

books.insert_many(book_list)
# Out:
# InsertManyResult([ObjectId('684ba1b28305bd419d640083'), ObjectId('684ba1b28305bd419d640084'), ObjectId('684ba1b28305bd419d640085'), ObjectId('684ba1b28305bd419d640086'), ObjectId('684ba1b28305bd419d640087'), ObjectId('684ba1b28305bd419d640088'), ObjectId('684ba1b28305bd419d640089'), ObjectId('684ba1b28305bd419d64008a'), ObjectId('684ba1b28305bd419d64008b'), ObjectId('684ba1b28305bd419d64008c'), ObjectId('684ba1b28305bd419d64008d'), ObjectId('684ba1b28305bd419d64008e'), ObjectId('684ba1b28305bd419d64008f'), ObjectId('684ba1b28305bd419d640090'), ObjectId('684ba1b28305bd419d640091'), ObjectId('684ba1b28305bd419d640092'), ObjectId('684ba1b28305bd419d640093'), ObjectId('684ba1b28305bd419d640094'), ObjectId('684ba1b28305bd419d640095'), ObjectId('684ba1b28305bd419d640096'), ObjectId('684ba1b28305bd419d640097'), ObjectId('684ba1b28305bd419d640098'), ObjectId('684ba1b28305bd419d640099'), ObjectId('684ba1b28305bd419d64009a'), ObjectId('684ba1b28305bd419d64009b'), ObjectId('684ba1b28305bd419d64
# ...

# %%
# 엑셀 저장
